# %%
# !pip install openai langchain langchain-openai langchain-community chromadb pypdf
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001D1EFE13F80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/openai/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001D1EEB84560>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/openai/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001D1F0029820>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/openai/
# ...

# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.12.8 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:48:34) [MSC v.1929 64 bit (AMD64)]
# C:\Users\lenovo\anaconda3\python.exe

# %%
# !{sys.executable}-m pip install openai
# Out:
# 'C:\Users\lenovo\anaconda3\python.exe-m' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %pip install openai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E02F49F9B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/openai/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E0329486E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/openai/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E032B54BF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/openai/
# ...

# %%
# %pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------------------- -------------- 1.0/1.7 MB 2.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.3/1.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: truststore
#     Found existing installation: truststore 0.8.0
#     Uninstalling truststore-0.8.0:
#       Successfully uninstalled truststore-0.8.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.2.0
#     Uninstalling anyio-4.2.0:
# ...

# %%
import openai
print(openai.__version__)
# Out:
# 3.1.0

# %%
import os

print(os.getenv("OPENAI_API_KEY") is not None)
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

print("OpenAI client connected successfully!")
# Out:
# OpenAI client connected successfully!

# %%
response = client.responses.create(
    model="gpt-5.6",
    input="Explain what an FIR is in one simple sentence."
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response = client.responses.create(
#       2     model="gpt-5.6",
#       3     input="Explain what an FIR is in one simple sentence."
#       4 )
#       6 print(response.output_text)
#
# File ~\anaconda3\Lib\site-packages\openai\resources\responses\responses.py:1031, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     989 def create(
#     990     self,
#     991     *,
# ...

# %%
# %pip install -U google-genai
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
# ...

# %%
from google import genai

print("Gemini package installed successfully!")
# Out:
# Gemini package installed successfully!

# %%
import os
print(os.getenv("GEMINI_API_KEY") is not None)
# Out:
# False

# %%
import os
print(os.environ.get("GEMINI_API_KEY"))
# Out:
# None

# %%
import getpass
import os

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter your Gemini API key: ")
# Out:
# Enter your Gemini API key:  ········

# %%
print(os.getenv("GEMINI_API_KEY") is not None)
# Out:
# True

# %%
from google import genai

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain what an FIR is in one simple sentence."
)

print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[10], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash",
#       7     contents="Explain what an FIR is in one simple sentence."
#       8 )
#      10 print(response.text)
#
# File ~\anaconda3\Lib\site-packages\google\genai\models.py:6600, in Models.generate_content(self, model, contents, config)
#    6594   parsed_config_to_call = _extra_utils.get_usage_header(
# ...

# %%
from google import genai
import os

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Explain what an FIR is in one simple sentence."
)

print(response.text)
# Out:
# An **FIR (First Information Report)** is an official document prepared by the police to begin an investigation after a serious crime is reported to them.

# %%
# %pip install pypdf
# Out:
# ...
#
# ...

# %%
from pypdf import PdfReader

pdf_path = "documents/BNSS_2023.pdf"

reader = PdfReader(pdf_path)

print("Number of pages:", len(reader.pages))
# Out:
# Number of pages: 282

# %%
text = ""

for page in reader.pages:
    page_text = page.extract_text()
    if page_text:
        text += page_text + "\n"

print("Total characters:", len(text))
# Out:
# Total characters: 823687

# %%
print(text[:3000])
# Out:
# 1
#
#
#
#
#
#
#
#
#
#
# The Bharatiya Nagarik Suraksha Sanhita, 2023
#  (ACT NO. 46 OF 2023)
# [As on the 6th October, 2025]
#
#
# 2
#
# LIST OF ABBREVIATIONS USED
# G.S.R.              . . . .            .            for           General Statutory Rules.
# S.O.                 . . . . .            ,,              Statutory Order.
# Notifn.  . . . . .  ,,    Notification.
#
# 3
#
# THE BHARATIYA NAGARIK SURAKSHA SANHITA, 2023
# _____________
# ARRANGEMENT OF SECTIONS
# __________
# CHAPTER I
# PRELIMINARY
# SECTIONS
# 1. Short title, extent and commencement.
# 2. Definitions.
# 3. Construction of references.
# 4. Trial of offences under Bharatiya Nyaya Sanhita, 2023 and other laws.
# 5. Saving.
# CHAPTER II
# CONSTITUTION OF CRIMINAL COURTS AND OFFICES
#
# 6. Classes of Criminal Courts.
# 7. Territorial divisions.
# 8. Court of Session.
# 9. Courts of Judicial Magistrates.
# 10. Chief Judicial Magistrate and Additional Chief Judicial Magistrate, etc.
# ...

# %%
# %pip install langchain-text-splitters
# Out:
# ...
#    ---------------------------------------- 0.0/565.9 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/565.9 kB ? eta -:--:--
#    ---------------------------------------- 565.9/565.9 kB 1.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/738.0 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/738.0 kB ? eta -:--:--
#    ---------------------------- ----------- 524.3/738.0 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 738.0/738.0 kB 1.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-text-splitters
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = splitter.split_text(text)

print("Number of chunks:", len(chunks))
print("\nFirst chunk:\n")
print(chunks[0])
# Out:
# Number of chunks: 1018
#
# First chunk:
#
# 1
#
#
#
#
#
#
#
#
#
#
# The Bharatiya Nagarik Suraksha Sanhita, 2023
#  (ACT NO. 46 OF 2023)
# [As on the 6th October, 2025]

# %%
# %pip install -U google-genai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
import os

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

result = client.models.embed_content(
    model="gemini-embedding-001",
    contents="What is an FIR?"
)

print(len(result.embeddings[0].values))
# Out:
# 3072

# %%
# %pip install chromadb
# Out:
# ...
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/23.5 MB ? eta -:--:--
#    - -------------------------------------- 0.8/23.5 MB 2.6 MB/s eta 0:00:09
#    -- ------------------------------------- 1.3/23.5 MB 2.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.8/23.5 MB 2.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.4/23.5 MB 2.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 3.1/23.5 MB 2.8 MB/s eta 0:00:08
#    ------ --------------------------------- 3.7/23.5 MB 2.8 MB/s eta 0:00:08
#    -------- ------------------------------- 4.7/23.5 MB 3.0 MB/s eta 0:00:07
#    --------- ------------------------------ 5.5/23.5 MB 3.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 6.6/23.5 MB 3.4 MB/s eta 0:00:06
#    ------------ --------------------------- 7.6/23.5 MB 3.5 MB/s eta 0:00:05
# ...

# %%
import chromadb

chroma_client = chromadb.PersistentClient(path="chroma_db")

collection = chroma_client.get_or_create_collection(
    name="bnss_documents"
)

print("ChromaDB created successfully!")
# Out:
# ChromaDB created successfully!

# %%
all_embeddings = []

batch_size = 50

for i in range(0, len(chunks), batch_size):
    batch = chunks[i:i + batch_size]

    result = client.models.embed_content(
        model="gemini-embedding-001",
        contents=batch
    )

    batch_embeddings = [e.values for e in result.embeddings]
    all_embeddings.extend(batch_embeddings)

    print(f"Processed {min(i + batch_size, len(chunks))}/{len(chunks)} chunks")
# Out:
# Processed 50/1018 chunks
# Processed 100/1018 chunks
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[23], line 8
#       5 for i in range(0, len(chunks), batch_size):
#       6     batch = chunks[i:i + batch_size]
# ----> 8     result = client.models.embed_content(
#       9         model="gemini-embedding-001",
#      10         contents=batch
#      11     )
#      13     batch_embeddings = [e.values for e in result.embeddings]
#      14     all_embeddings.extend(batch_embeddings)
#
# File ~\anaconda3\Lib\site-packages\google\genai\models.py:6455, in Models.embed_content(self, model, contents, config)
#    6453   if 'gemini-embedding-2' in model:
#    6454     contents = t.t_contents(contents)  # type: ignore[assignment]
# -> 6455   return self._embed_content(model=model, contents=contents, config=config)
#    6457 if t.t_is_vertex_embed_content_model(model):
# ...

# %%
print(len(all_embeddings))
# Out:
# 100

# %%
import time

batch_size = 10

for i in range(100, len(chunks), batch_size):
    batch = chunks[i:i + batch_size]

    result = client.models.embed_content(
        model="gemini-embedding-001",
        contents=batch
    )

    batch_embeddings = [e.values for e in result.embeddings]
    all_embeddings.extend(batch_embeddings)

    print(f"Processed {min(i + batch_size, len(chunks))}/{len(chunks)} chunks")

    time.sleep(2)
# Out:
# Processed 110/1018 chunks
# Processed 120/1018 chunks
# Processed 130/1018 chunks
# Processed 140/1018 chunks
# Processed 150/1018 chunks
# Processed 160/1018 chunks
# Processed 170/1018 chunks
# Processed 180/1018 chunks
# Processed 190/1018 chunks
# Processed 200/1018 chunks
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[25], line 8
#       5 for i in range(100, len(chunks), batch_size):
#       6     batch = chunks[i:i + batch_size]
# ----> 8     result = client.models.embed_content(
#       9         model="gemini-embedding-001",
#      10         contents=batch
#      11     )
#      13     batch_embeddings = [e.values for e in result.embeddings]
#      14     all_embeddings.extend(batch_embeddings)
#
# File ~\anaconda3\Lib\site-packages\google\genai\models.py:6455, in Models.embed_content(self, model, contents, config)
# ...

# %%
print(len(all_embeddings))
# Out:
# 200

# %%
# %pip install sentence-transformers
# Out:
# ...
#    ---------------------------------------- 0.0/611.3 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/611.3 kB ? eta -:--:--
#    ---------------------------------------- 611.3/611.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/122.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/122.1 MB ? eta -:--:--
#    ---------------------------------------- 0.8/122.1 MB 2.4 MB/s eta 0:00:51
#     --------------------------------------- 1.6/122.1 MB 2.7 MB/s eta 0:00:45
#     --------------------------------------- 2.1/122.1 MB 2.6 MB/s eta 0:00:46
#     --------------------------------------- 2.6/122.1 MB 2.7 MB/s eta 0:00:46
#    - -------------------------------------- 3.1/122.1 MB 2.7 MB/s eta 0:00:44
#    - -------------------------------------- 3.1/122.1 MB 2.7 MB/s eta 0:00:44
#    - -------------------------------------- 3.1/122.1 MB 2.7 MB/s eta 0:00:44
# ...

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

print("Local embedding model loaded successfully!")
# Out:
# ...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\lenovo\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\lenovo\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
test_embedding = embedding_model.encode("What is an FIR?")

print("Embedding size:", len(test_embedding))
# Out:
# Embedding size: 384

# %%
local_embeddings = embedding_model.encode(
    chunks,
    batch_size=32,
    show_progress_bar=True
)

print("Number of embeddings:", len(local_embeddings))
print("Embedding size:", len(local_embeddings[0]))
# Out:
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Number of embeddings: 1018
# Embedding size: 384

# %%
collection.add(
    ids=[f"chunk_{i}" for i in range(len(chunks))],
    documents=chunks,
    embeddings=local_embeddings.tolist()
)

print("All 1,018 chunks stored in ChromaDB!")
# Out:
# All 1,018 chunks stored in ChromaDB!

# %%
question = "What is the procedure for reporting a cognizable offence?"

question_embedding = embedding_model.encode(question).tolist()

results = collection.query(
    query_embeddings=[question_embedding],
    n_results=3
)

for i, document in enumerate(results["documents"][0]):
    print(f"\n--- Result {i + 1} ---\n")
    print(document)
# Out:
# --- Result 1 ---
#
# CHAPTER XV
# CONDITIONS REQUISITE FOR INITIATION OF PROCEEDINGS
# 210. Cognizance of offences by Magistrate .—(1) Subject to the provisions of this Chapter, any
# Magistrate of the first class, and any Magistrate of the second class specially empowered in this behalf
# under sub-section (2), may take cognizance of any offence—
# (a) upon receiving a complaint of facts, including any complaint filed by a person authorised under
# any special law, which constitutes such offence;
# (b) upon a police report (submitted in any mode including electronic mode) of such facts;
# 84
#
# (c) upon information received from any person other than a police officer, or upon his own
# knowledge, that such offence has been committed.
# (2) The Chief Judicial Magistrate may empower any Magistrate of the second class to take cognizance
# under sub-section (1) of such offences as are within his competence to inquire into or try.
#
# --- Result 2 ---
#
# Government;
# ...

# %%
question = "What is the procedure for reporting a cognizable offence?"

question_embedding = embedding_model.encode(question).tolist()

results = collection.query(
    query_embeddings=[question_embedding],
    n_results=3
)

context = "\n\n".join(results["documents"][0])

prompt = f"""
You are a legal information assistant.

Answer the user's question using ONLY the information
provided in the context below.

If the answer cannot be found in the context, say:
"I could not find this information in the provided BNSS document."

Do not make up legal information.

Context:
{context}

Question:
{question}

Answer:
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[33], line 32
#      10 context = "\n\n".join(results["documents"][0])
#      12 prompt = f"""
#      13 You are a legal information assistant.
#      14
#    (...)
#      29 Answer:
#      30 """
# ---> 32 response = client.models.generate_content(
#      33     model="gemini-2.5-flash",
#      34     contents=prompt
#      35 )
#      37 print(response.text)
#
# File ~\anaconda3\Lib\site-packages\google\genai\models.py:6600, in Models.generate_content(self, model, contents, config)
#    6594   parsed_config_to_call = _extra_utils.get_usage_header(
#    6595       parsed_config_to_call,
#    6596       types.GenerateContentConfig,
#    6597       'afc',
#    6598   )
#    6599 i += 1
# -> 6600 response = self._generate_content(
#    6601     model=model, contents=contents, config=parsed_config_to_call
#    6602 )
# ...

# %%
question = "What is the procedure for reporting a cognizable offence?"

question_embedding = embedding_model.encode(question).tolist()

results = collection.query(
    query_embeddings=[question_embedding],
    n_results=3
)

context = "\n\n".join(results["documents"][0])

prompt = f"""
You are a legal information assistant.

Answer the user's question using ONLY the information
provided in the context below.

If the answer cannot be found in the context, say:
"I could not find this information in the provided BNSS document."

Do not make up legal information.

Context:
{context}

Question:
{question}

Answer:
"""

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)

print(response.text)
# Out:
# I could not find this information in the provided BNSS document.

# %%
question = "How can a person report information about a cognizable offence to the police?"

question_embedding = embedding_model.encode(question).tolist()

results = collection.query(
    query_embeddings=[question_embedding],
    n_results=5
)

for i, document in enumerate(results["documents"][0]):
    print(f"\n--- Result {i + 1} ---\n")
    print(document[:2000])
# Out:
# --- Result 1 ---
#
# shall have all the powers of an officer in charge of the police station in relation to that offence failing which
# such aggrieved person may make an application to the Magistrate.
# 174. Information as to non -cognizable cases and investigation of such cases. —(1) When
# information is given to an officer in charge of a police station of the commission within the limits of such
# station of a non-cognizable offence, he shall enter or cause to be entered the substance of the information
# in a book to be kept by such off icer in such form as the State Government may by rules prescribe in this
# behalf, and,—
# (i) refer the informant to the Magistrate;
# (ii) forward the daily diary report of all such cases fortnightly to the Magistrate.
# (2) No police officer shall investigate a non -cognizable case without the order of a Magistrate having
# power to try such case or commit the case for trial.
#
# --- Result 2 ---
#
# ...

# %%
question = "How can a person report information about a cognizable offence to the police?"

question_embedding = embedding_model.encode(question).tolist()

results = collection.query(
    query_embeddings=[question_embedding],
    n_results=5
)

context = "\n\n".join(results["documents"][0])

prompt = f"""
You are a legal information assistant for the Bharatiya Nagarik Suraksha Sanhita (BNSS), 2023.

Answer the user's question using ONLY the information provided in the context.

Give a clear, simple answer and mention the relevant BNSS section number.

If the information is not present in the context, say:
"I could not find this information in the provided BNSS document."

Do not invent or assume legal information.

Context:
{context}

User Question:
{question}

Answer:
"""

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)

print(response.text)
# Out:
# Based on the provided document, a person can report information about a cognizable offence (regardless of the area where the offence occurred) to an officer in charge of a police station in the following ways:
#
# * **Orally:** If given orally, the officer (or someone under their direction) must write it down and read it back to the informant.
# * **By electronic communication.**
#
# **Relevant Section:** Section 173(1) of the BNSS.
